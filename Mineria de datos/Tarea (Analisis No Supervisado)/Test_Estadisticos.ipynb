# %% [markdown]
# <div style="border-top: 4px solid #b85300; border-bottom: 1px solid #b85300; padding: 36px 0 28px; margin-bottom: 4px;">
#   <h1 style="font-family: 'Palatino Linotype', Palatino, 'Book Antiqua', serif; font-size: 2.2em; color: #000000; margin: 0 0 10px; font-weight: 700; letter-spacing: 0.5px;">Análisis Estadístico</h1>
#   <p style="font-family: 'Palatino Linotype', Palatino, 'Book Antiqua', serif; font-size: 1.05em; color: #000000; margin: 0; font-style: italic;">Comportamiento y Perfiles de Personalidad &mdash; Nutrición y Densidad Calórica</p>
# </div>

# %% [markdown]
# <div style="margin: 32px 0 8px; border-left: 3px solid #b85300; padding-left: 16px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.75em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">CONFIGURACIÓN</span>
#   <h2 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.35em; color: #000000; margin: 4px 0 0; font-weight: 600;">Librerías</h2>
# </div>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import scripts.Dataset_1 as gi
import scripts.Dataset_2 as gii

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="border-top: 1px solid #b85300; margin-top: 40px; padding-top: 28px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.72em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">Dataset 1</span>
#   <h1 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.85em; color: #000000; margin: 6px 0 0; font-weight: 700;">Comportamiento y Perfiles de Personalidad</h1>
# </div>

# %%
df1 = pd.read_csv('data/personality_synthetic_dataset.csv')
df1.head()
# Out:
#   personality_type  social_energy  alone_time_preference  talkativeness  \
# 0        Extrovert       6.794295               3.854670       8.725446
# 1         Ambivert       6.378988               5.731157       7.029529
# 2         Ambivert       7.459421               6.322263       3.922269
# 3        Extrovert       6.159626               3.097837       6.019093
# 4        Introvert       5.568462               6.986722       3.913240
#
#    deep_reflection  group_comfort  party_liking  listening_skill   empathy  \
# 0         2.515151       7.097368      8.588762         6.774799  6.430132
# 1         7.274493       4.111199      3.258248         5.550909  3.958179
# 2         4.622261       5.343276      7.452152         9.483990  6.127654
# 3         1.965440       7.837140     10.000000         9.436733  8.949684
# 4         9.926161       1.650483      0.362298         7.470387  6.756837
#
#    creativity  ...  spontaneity  adventurousness  reading_habit  \
# ...

# %% [markdown]
# <div style="margin: 32px 0 8px; border-left: 3px solid #b85300; padding-left: 16px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.75em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">Fase 1</span>
#   <h2 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.35em; color: #000000; margin: 4px 0 0; font-weight: 600;">Minería Visual (EDA)</h2>
# </div>

# %% [markdown]
# #### Distribuciones Cruzadas
# Distribución de variables numéricas segmentada por `personality_type` y `talkativeness`.

# %%
importlib.reload(gi)
from scripts.Dataset_1 import Distribuciones_Cruzadas

df = pd.read_csv('data/personality_synthetic_dataset.csv')

Distribuciones_Cruzadas(df, hue='personality_type')
Distribuciones_Cruzadas(df, hue='talkativeness')

# %% [markdown]
# #### Análisis de Outliers
# Detección de valores atípicos mediante boxplots agrupados por `personality_type`.

# %%
importlib.reload(gi)
from scripts.Dataset_1 import Analisis_Outliers

df = pd.read_csv('data/personality_synthetic_dataset.csv')
Analisis_Outliers(df, hue='personality_type')

# %% [markdown]
# #### Estructura de Correlación
# Mapa de calor de la matriz de correlación entre variables numéricas.

# %%
importlib.reload(gi)
from scripts.Dataset_1 import Estructura_Correlacional

Estructura_Correlacional(df)

# %% [markdown]
# <div style="margin: 32px 0 8px; border-left: 3px solid #b85300; padding-left: 16px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.75em; color: #ffffff; text-transform: uppercase; letter-spacing: 1.5px;">Fase 2</span>
#   <h2 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.35em; color: #ffffff; margin: 4px 0 0; font-weight: 600;">Contraste de Hipótesis e Inferencia</h2>
# </div>

# %% [markdown]
# #### Prueba t de Student
# Comparación de medias de `risk_taking` entre los grupos de personalidad.

# %%
importlib.reload(gi)
from scripts.Dataset_1 import Prueba_t_student

Prueba_t_student(df, 'risk_taking')
# Out:
# Variable: risk_taking
# Estadístico t: 23519.02116794664
# Valor p: 0.0000
# Resultado: Diferencia significativa

# %% [markdown]
# #### MANOVA
# Análisis multivariado de varianza para evaluar diferencias simultáneas en múltiples variables de respuesta.

# %%
importlib.reload(gi)
from scripts.Dataset_1 import Analisis_MANOVA

Analisis_MANOVA(df)
# Out:
#                      Multivariate linear model
# ...
#
# --------------------------------------------------------------------
#        Intercept         Value  Num DF   Den DF     F Value   Pr > F
# --------------------------------------------------------------------
#           Wilks' lambda  0.0440 3.0000 19995.0000 144655.0115 0.0000
#          Pillai's trace  0.9560 3.0000 19995.0000 144655.0115 0.0000
#  Hotelling-Lawley trace 21.7037 3.0000 19995.0000 144655.0115 0.0000
#     Roy's greatest root 21.7037 3.0000 19995.0000 144655.0115 0.0000
# --------------------------------------------------------------------
#
# --------------------------------------------------------------------
#        personality_type    Value  Num DF   Den DF    F Value  Pr > F
# --------------------------------------------------------------------
#              Wilks' lambda 0.5967 6.0000 39990.0000 1962.9982 0.0000
#             Pillai's trace 0.4034 6.0000 39992.0000 1684.0187 0.0000
# ...

# %% [markdown]
# <div style="margin: 32px 0 8px; border-left: 3px solid #b85300; padding-left: 16px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.75em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">Fase 3</span>
#   <h2 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.35em; color: #000000; margin: 4px 0 0; font-weight: 600;">Clasificación &mdash; Regresión Logística</h2>
# </div>

# %% [markdown]
# #### Regresión Logística
# Entrenamiento y evaluación del modelo de clasificación de tipo de personalidad.

# %%
importlib.reload(gi)
from scripts.Dataset_1 import Regresion_Logistica

Regresion_Logistica(df)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453878
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:        high_leadership   No. Observations:                20000
# Model:                          Logit   Df Residuals:                    19996
# Method:                           MLE   Df Model:                            3
# Date:                mar, 26 may 2026   Pseudo R-squ.:                  0.2227
# Time:                        12:21:43   Log-Likelihood:                -9077.6
# converged:                       True   LL-Null:                       -11678.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# <div style="border-top: 1px solid #b85300; margin-top: 48px; padding-top: 28px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.72em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">Dataset 2</span>
#   <h1 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.85em; color: #000000; margin: 6px 0 0; font-weight: 700;">Análisis Nutricional y Densidad Calórica</h1>
# </div>

# %%
df2 = pd.read_csv('data/daily_food_nutrition_dataset.csv', on_bad_lines='skip')
df2.head()
# Out:
#                      Food_Item       Category  Calories (kcal)  Protein (g)  \
# 0     Scrambled Eggs (2 large)  Protein/Dairy              180         12.0
# 1  Whole Wheat Toast (1 slice)          Grain               80          4.0
# 2               Coffee (black)       Beverage                5          0.3
# 3                       Banana          Fruit              105          1.3
# 4        Grilled Chicken Salad   Meal/Protein              350         30.0
#
#    Carbohydrates (g)  Fat (g)  Fiber (g)  Sugars (g)  Sodium (mg)  \
# 0                2.0     14.0        0.0         1.0          180
# 1               14.0      1.0        2.0         2.0          140
# 2                0.0      0.1        0.0         0.0            5
# 3               27.0      0.4        3.1        14.0            1
# 4               10.0     20.0        5.0         4.0          400
#
#    Cholesterol (mg)  Meal_Type  Water_Intake (ml)
# 0               370  Breakfast                250
# ...

# %% [markdown]
# <div style="margin: 32px 0 8px; border-left: 3px solid #b85300; padding-left: 16px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.75em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">Fase 1</span>
#   <h2 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.35em; color: #000000; margin: 4px 0 0; font-weight: 600;">Minería y Perfilamiento</h2>
# </div>

# %% [markdown]
# #### Composición por Categoría
# Distribución de macronutrientes y calorías agrupados por tipo de alimento.

# %%
importlib.reload(gii)
from scripts.Dataset_2 import Composicion_Categorica
print(df2.columns.tolist())
Composicion_Categorica(df2)
# Out:
# ['Food_Item', 'Category', 'Calories (kcal)', 'Protein (g)', 'Carbohydrates (g)', 'Fat (g)', 'Fiber (g)', 'Sugars (g)', 'Sodium (mg)', 'Cholesterol (mg)', 'Meal_Type', 'Water_Intake (ml)']

# %% [markdown]
# #### Relación Calórica
# Exploración de la relación entre densidad calórica y composición de macronutrientes.

# %%
importlib.reload(gii)
from scripts.Dataset_2 import Relacion_Caloricas

Relacion_Caloricas(df2)

# %% [markdown]
# <div style="margin: 32px 0 8px; border-left: 3px solid #b85300; padding-left: 16px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.75em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">Fase 2</span>
#   <h2 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.35em; color: #000000; margin: 4px 0 0; font-weight: 600;">ANOVA y Comparaciones Múltiples</h2>
# </div>

# %% [markdown]
# #### ANOVA
# Análisis de varianza de un factor para evaluar diferencias en el contenido de azúcar entre categorías.

# %%
importlib.reload(gii)
from scripts.Dataset_2 import ANOVA_Sugar

ANOVA_Sugar(df2)
# Out:
# F-statistic: 51.54308297689508
# Valor p: 0.0000
# Resultado: Diferencia significativa

# %% [markdown]
# #### Post-Hoc
# Comparaciones múltiples pareadas para identificar qué grupos difieren significativamente.

# %%
importlib.reload(gii)
from scripts.Dataset_2 import PostHoc_Sugar

PostHoc_Sugar(df2)

# %% [markdown]
# <div style="margin: 32px 0 8px; border-left: 3px solid #b85300; padding-left: 16px;">
#   <span style="font-family: 'Courier New', monospace; font-size: 0.75em; color: #000000; text-transform: uppercase; letter-spacing: 1.5px;">Fase 3</span>
#   <h2 style="font-family: 'Palatino Linotype', Palatino, serif; font-size: 1.35em; color: #000000; margin: 4px 0 0; font-weight: 600;">Regresión Lineal Múltiple</h2>
# </div>

# %% [markdown]
# #### Regresión Lineal Múltiple
# Ajuste y evaluación del modelo predictivo para densidad calórica a partir de macronutrientes.

# %%
importlib.reload(gii)
from scripts.Dataset_2 import Regresion_Lineal_Multiple

Regresion_Lineal_Multiple(df2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Calories (kcal)   R-squared:                       0.984
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     9718.
# Date:                mar, 26 may 2026   Prob (F-statistic):               0.00
# Time:                        12:21:55   Log-Likelihood:                -2772.4
# No. Observations:                 645   AIC:                             5555.
# Df Residuals:                     640   BIC:                             5577.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 2.3055      1.047      2.202      0.028       0.249       4.362
# ...
